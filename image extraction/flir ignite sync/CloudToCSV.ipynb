# %%
# !pip install flyr
# !pip install exifread
# !pip install numpy
# !pip install flirimageextractor
# Out:
# Requirement already satisfied: flirpy in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (0.3.0)
# Requirement already satisfied: pyserial in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from flirpy) (3.5)
# Requirement already satisfied: opencv-python-headless in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from flirpy) (4.12.0.88)
# Requirement already satisfied: tqdm in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from flirpy) (4.67.1)
# Requirement already satisfied: numpy in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from flirpy) (2.2.6)
# Requirement already satisfied: pyudev in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from flirpy) (0.24.4)
# Requirement already satisfied: psutil in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from flirpy) (5.9.0)
# Requirement already satisfied: natsort in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from flirpy) (8.4.0)
# Requirement already satisfied: libusb in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from flirpy) (1.0.29)
# Requirement already satisfied: pyusb in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from flirpy) (1.3.1)
# Requirement already satisfied: pyftdi in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from flirpy) (0.57.1)
# Requirement already satisfied: Pillow in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from flirpy) (10.4.0)
# Requirement already satisfied: setuptools>=80.9.0 in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from libusb->flirpy) (80.9.0)
# Requirement already satisfied: pkg-about>=1.3.6 in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from libusb->flirpy) (2.0.5)
# Requirement already satisfied: colorama in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from tqdm->flirpy) (0.4.6)
# Requirement already satisfied: packaging>=25.0.0 in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from pkg-about>=1.3.6->libusb->flirpy) (25.0)
# Requirement already satisfied: exifread in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (3.5.1)
# Requirement already satisfied: numpy in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (2.2.6)
# Requirement already satisfied: flirimageextractor in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (1.5.9)
# Requirement already satisfied: keyring<26.0.0,>=25.2.1 in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from flirimageextractor) (25.7.0)
# Requirement already satisfied: loguru<0.8.0,>=0.7.2 in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from flirimageextractor) (0.7.3)
# Requirement already satisfied: logzero<2.0.0,>=1.7.0 in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from flirimageextractor) (1.7.0)
# Requirement already satisfied: matplotlib<4.0.0,>=3.9.0 in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from flirimageextractor) (3.10.7)
# Requirement already satisfied: numpy<3.0.0,>=2.0.0 in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from flirimageextractor) (2.2.6)
# Requirement already satisfied: opencv-python<5.0.0.0,>=4.10.0.84 in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from flirimageextractor) (4.12.0.88)
# Requirement already satisfied: pillow<11.0.0,>=10.3.0 in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from flirimageextractor) (10.4.0)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from flirimageextractor) (2.32.5)
# Requirement already satisfied: sphinx<8.0.0,>=7.3.7 in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from flirimageextractor) (7.4.7)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.4 in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from flirimageextractor) (4.67.1)
# Requirement already satisfied: pywin32-ctypes>=0.2.0 in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from keyring<26.0.0,>=25.2.1->flirimageextractor) (0.2.0)
# Requirement already satisfied: importlib_metadata>=4.11.4 in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from keyring<26.0.0,>=25.2.1->flirimageextractor) (6.0.0)
# Requirement already satisfied: jaraco.classes in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from keyring<26.0.0,>=25.2.1->flirimageextractor) (3.2.1)
# Requirement already satisfied: jaraco.functools in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from keyring<26.0.0,>=25.2.1->flirimageextractor) (4.3.0)
# Requirement already satisfied: jaraco.context in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from keyring<26.0.0,>=25.2.1->flirimageextractor) (6.0.1)
# Requirement already satisfied: colorama>=0.3.4 in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from loguru<0.8.0,>=0.7.2->flirimageextractor) (0.4.6)
# Requirement already satisfied: win32-setctime>=1.0.0 in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from loguru<0.8.0,>=0.7.2->flirimageextractor) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.9.0->flirimageextractor) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.9.0->flirimageextractor) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.9.0->flirimageextractor) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.9.0->flirimageextractor) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.9.0->flirimageextractor) (25.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.9.0->flirimageextractor) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.9.0->flirimageextractor) (2.8.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.3->flirimageextractor) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.3->flirimageextractor) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.3->flirimageextractor) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.3->flirimageextractor) (2025.11.12)
# Requirement already satisfied: sphinxcontrib-applehelp in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from sphinx<8.0.0,>=7.3.7->flirimageextractor) (1.0.2)
# Requirement already satisfied: sphinxcontrib-devhelp in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from sphinx<8.0.0,>=7.3.7->flirimageextractor) (1.0.2)
# Requirement already satisfied: sphinxcontrib-jsmath in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from sphinx<8.0.0,>=7.3.7->flirimageextractor) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from sphinx<8.0.0,>=7.3.7->flirimageextractor) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from sphinx<8.0.0,>=7.3.7->flirimageextractor) (2.0.0)
# Requirement already satisfied: sphinxcontrib-qthelp in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from sphinx<8.0.0,>=7.3.7->flirimageextractor) (1.0.3)
# Requirement already satisfied: Jinja2>=3.1 in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from sphinx<8.0.0,>=7.3.7->flirimageextractor) (3.1.2)
# Requirement already satisfied: Pygments>=2.17 in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from sphinx<8.0.0,>=7.3.7->flirimageextractor) (2.19.2)
# Requirement already satisfied: docutils<0.22,>=0.20 in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from sphinx<8.0.0,>=7.3.7->flirimageextractor) (0.21.2)
# Requirement already satisfied: snowballstemmer>=2.2 in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from sphinx<8.0.0,>=7.3.7->flirimageextractor) (2.2.0)
# Requirement already satisfied: babel>=2.13 in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from sphinx<8.0.0,>=7.3.7->flirimageextractor) (2.17.0)
# Requirement already satisfied: alabaster~=0.7.14 in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from sphinx<8.0.0,>=7.3.7->flirimageextractor) (0.7.16)
# Requirement already satisfied: imagesize>=1.3 in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from sphinx<8.0.0,>=7.3.7->flirimageextractor) (1.4.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from importlib_metadata>=4.11.4->keyring<26.0.0,>=25.2.1->flirimageextractor) (3.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from Jinja2>=3.1->sphinx<8.0.0,>=7.3.7->flirimageextractor) (2.1.1)
# Requirement already satisfied: six>=1.5 in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.9.0->flirimageextractor) (1.16.0)
# Requirement already satisfied: more-itertools in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from jaraco.classes->keyring<26.0.0,>=25.2.1->flirimageextractor) (8.12.0)
# Requirement already satisfied: backports.tarfile in c:\users\st1mohamna\appdata\local\anaconda3\lib\site-packages (from jaraco.context->keyring<26.0.0,>=25.2.1->flirimageextractor) (1.2.0)

# %%
import os
import csv
import json
import subprocess
import flyr  # pip install flyr

# --- CONFIGURATION ---

# 1. Path Setup
try:
    base_dir = os.path.dirname(os.path.abspath(__file__))
except NameError:
    base_dir = os.getcwd()

INPUT_FOLDER = os.path.join(base_dir, "100_FLIR")
OUTPUT_CSV = os.path.join(base_dir, "Thermal_Data_Log.csv")

# 2. ExifTool Location
EXIFTOOL_PATH = os.path.join(base_dir, "exiftool-12.35.exe") 


# --- HELPER FUNCTIONS ---

def load_existing_records(csv_path):
    existing_signatures = set()
    
    if not os.path.exists(csv_path):
        return existing_signatures, False 

    try:
        with open(csv_path, 'r', encoding='utf-8') as f:
            reader = csv.DictReader(f)
            for row in reader:
                ts = str(row.get("Timestamp", "")).strip()
                sn = str(row.get("Serial Number", "")).strip()
                if ts and sn:
                    existing_signatures.add((ts, sn))
        return existing_signatures, True
    except Exception as e:
        print(f"Warning: Could not read existing CSV ({e}). Starting fresh.")
        return existing_signatures, False

def get_folder_metadata_batch(folder_path, tool_path):
    print("Scanning metadata for all files...")
    tool_cmd = tool_path if os.path.exists(tool_path) else "exiftool"
    
    try:
        cmd = [
            tool_cmd, '-j', '-n', '-r',
            '-DateTimeOriginal', '-CameraModel', '-CameraSerialNumber',
            '-SerialNumber', '-Emissivity', '-ObjectDistance', 
            folder_path
        ]
        
        flags = 0
        if os.name == 'nt': 
            flags = subprocess.CREATE_NO_WINDOW

        result = subprocess.run(cmd, capture_output=True, text=True, creationflags=flags)
        
        if not result.stdout:
            return []

        return json.loads(result.stdout)

    except Exception as e:
        print(f"Error in metadata extraction: {e}")
        return []

def process_incremental():
    headers = [
        "File Name", "Timestamp", "Camera Model", "Serial Number", 
        "Center Temp (C)", "Max Temp (C)", "Min Temp (C)", 
        "Avg Temp (C)", "Delta Temp (C)", 
        "Emissivity", "Distance", "Status"
    ]

    if not os.path.exists(INPUT_FOLDER):
        print(f"Error: Input folder not found: {INPUT_FOLDER}")
        return

    # 1. LOAD EXISTING DB
    existing_sigs, csv_exists = load_existing_records(OUTPUT_CSV)
    print(f"Found {len(existing_sigs)} existing records in CSV.")

    # 2. GET METADATA BATCH
    all_metadata = get_folder_metadata_batch(INPUT_FOLDER, EXIFTOOL_PATH)
    
    # 3. FILTER: Find only NEW images
    files_to_process = []
    
    for meta in all_metadata:
        # FORCE STRING CONVERSION (Fixes AttributeError)
        ts = str(meta.get("DateTimeOriginal", "")).strip()
        sn = str(meta.get("CameraSerialNumber", "")).strip()
        
        if not sn or sn == "None":
             sn = str(meta.get("SerialNumber", "")).strip()

        # Check if this exact shot is already in our CSV
        if (ts, sn) in existing_sigs:
            continue 
            
        files_to_process.append(meta)

    total_new = len(files_to_process)
    print(f"New images to process: {total_new}")
    
    if total_new == 0:
        print("Everything is up to date.")
        return

    # 4. PROCESS ONLY NEW FILES
    with open(OUTPUT_CSV, mode='a', newline='', encoding='utf-8') as f:
        writer = csv.writer(f)
        
        if not csv_exists:
            writer.writerow(headers)
        
        for i, meta in enumerate(files_to_process):
            full_path = meta.get('SourceFile')
            filename = os.path.basename(full_path)
            
            # --- PROGRESS INDICATOR ---
            # end='\r' returns cursor to start of line
            # " "*20 clears any leftover text from previous longer filenames
            print(f"Processing [{i+1}/{total_new}] {filename}" + " "*20, end='\r', flush=True)

            try:
                # --- A. Thermal Processing ---
                thermogram = flyr.unpack(full_path)
                thermal_data = thermogram.celsius
                
                min_t = thermal_data.min()
                max_t = thermal_data.max()
                avg_t = thermal_data.mean()
                delta_t = max_t - min_t
                
                h, w = thermal_data.shape
                center_t = thermal_data[h//2, w//2]

                # --- B. Prepare Data for Writing ---
                row_ts = str(meta.get("DateTimeOriginal", "Unknown"))
                row_model = str(meta.get("CameraModel", "Unknown"))
                
                row_sn = str(meta.get("CameraSerialNumber", ""))
                if not row_sn or row_sn == "None":
                    row_sn = str(meta.get("SerialNumber", "Unknown"))

                writer.writerow([
                    filename,
                    row_ts,
                    row_model,
                    row_sn,
                    f"{center_t:.1f}",
                    f"{max_t:.1f}",     
                    f"{min_t:.1f}",     
                    f"{avg_t:.1f}",
                    f"{delta_t:.1f}",
                    meta.get("Emissivity", "N/A"),
                    meta.get("ObjectDistance", "N/A"),
                    "Success"
                ])
                
                if i % 10 == 0: f.flush()
                
            except Exception as e:
                writer.writerow([filename, str(meta.get("DateTimeOriginal")), "", "", "", "", "", "", "", "", "", f"Error: {str(e)}"])

    # Clear the progress line and print done
    print("\n" + "-"*50)
    print(f"Done! Added {total_new} new records.")

if __name__ == "__main__":
    process_incremental()
# Out:
# Found 14 existing records in CSV.
# Scanning metadata for all files...
# New images to process: 2
# Processing [2/2] FLIR0019.jpg
# --------------------------------------------------
# Done! Added 2 new records.

# %%
################################################### MAZEN  - DataFrame Viewer ##################################################
import pandas as pd

df = pd.read_csv("Thermal_Data_Log.csv")
df
# Out:
#        File Name                      Timestamp Camera Model  Serial Number  \
# 0   FLIR0003.jpg  2025:11:24 14:30:18.107+02:00  FLIR E5 Pro       13333134
